# %% [markdown]
# # Speed Bumps
# Speed Bumps are generally the biggest nuisance when you are driving anywhere. They exist to make you slow down or else risk severely damaging your car, and are generally a bit annoying even if their placement usually makes sense.
#
# With that in mind, the less speed bumps there are in a neighborhood, the less annoying it is to drive through it. Therefore, those are the neighborhoods we are considering to be better.
#
# The main issue with this dataset is that there isn't actually too much data to work with. There are two main issues that I could think of: either the person who made the dataset hasn't actually finished it, or most of the speed bumps I could think of are actually privately maintained, and are therefore not regulated by any municipality and thus the data is not made public. Also most that I can think of are in parking garages.

# %%
import pandas as pd
import numpy as np

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
bumps = pd.read_csv("https://data.wprdc.org/datastore/dump/37b2ac41-ae8e-4de1-8405-157e05dc3640",
                   index_col = "id")
bumps
# Out:
#             hump_id  locator_address_number locator_street  pavement  \
# id
# 430808404       NaN                  4337.0      Saline St       NaN
# 1520886592      NaN                     NaN   Summerset Dr       NaN
# 858537521       NaN                   517.0       Gold Way       NaN
# 297775878       NaN                   584.0       Gold Way       NaN
# 1061197751      NaN                   647.0    Melwood Ave       NaN
# 25169591        NaN                  4224.0      Saline St       NaN
# 2056880845      NaN                  2146.0       Jacob St       NaN
# 1735565853      NaN                  2082.0       Jacob St       NaN
# 857069875       NaN                  2013.0       Jacob St       NaN
# 1822275525      NaN                  1937.0       Jacob St       NaN
# 185819892       NaN                  5334.0  Darlington Rd       NaN
# 1324735109      NaN                  5362.0  Darlington Rd       NaN
# ...

# %%
bumps['neighborhood'].value_counts()
# Out:
# Squirrel Hill South    9
# Polish Hill            6
# North Oakland          5
# Homewood South         4
# Brookline              4
# Squirrel Hill North    3
# South Side Flats       3
# Bloomfield             3
# Mount Washington       3
# Central Oakland        1
# Name: neighborhood, dtype: int64
